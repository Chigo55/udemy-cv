# %%
import numpy as np
from numpy import genfromtxt

# %%
data = genfromtxt('../Computer-Vision-with-Python/DATA/bank_note_data.txt', delimiter=',')

# %%
labels = data[:, 4]

# %%
features = data[:, 0:4]

# %%
X = features
y = labels

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_object = MinMaxScaler()

# %%
scaler_object.fit(X_train)
# Out:
# MinMaxScaler()

# %%
scaled_X_train = scaler_object.transform(X_train)

# %%
scaled_X_test = scaler_object.transform(X_test)

# %%
from keras import Input
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Input(shape=(4,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# model = Sequential()

# model.add(Dense(4, input_dim=4, activation='relu'))
# model.add(Dense(8, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69 (276.00 B)
#  Trainable params: 69 (276.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 29/29 - 1s - 19ms/step - accuracy: 0.5299 - loss: 1.1644
# Epoch 2/50
# 29/29 - 0s - 1ms/step - accuracy: 0.5571 - loss: 0.7748
# Epoch 3/50
# 29/29 - 0s - 1ms/step - accuracy: 0.6028 - loss: 0.5862
# Epoch 4/50
# 29/29 - 0s - 1ms/step - accuracy: 0.6964 - loss: 0.5301
# Epoch 5/50
# 29/29 - 0s - 1ms/step - accuracy: 0.7541 - loss: 0.4957
# Epoch 6/50
# 29/29 - 0s - 1ms/step - accuracy: 0.7573 - loss: 0.4641
# Epoch 7/50
# 29/29 - 0s - 1ms/step - accuracy: 0.7748 - loss: 0.4359
# Epoch 8/50
# 29/29 - 0s - 1ms/step - accuracy: 0.7922 - loss: 0.4095
# Epoch 9/50
# 29/29 - 0s - 1ms/step - accuracy: 0.8651 - loss: 0.3847
# Epoch 10/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9304 - loss: 0.3626
# Epoch 11/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9369 - loss: 0.3419
# Epoch 12/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9434 - loss: 0.3238
# Epoch 13/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9489 - loss: 0.3073
# Epoch 14/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9489 - loss: 0.2925
# Epoch 15/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9489 - loss: 0.2789
# Epoch 16/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9499 - loss: 0.2666
# Epoch 17/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9499 - loss: 0.2554
# Epoch 18/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9543 - loss: 0.2451
# Epoch 19/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9543 - loss: 0.2357
# Epoch 20/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9554 - loss: 0.2271
# Epoch 21/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9587 - loss: 0.2187
# Epoch 22/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9587 - loss: 0.2110
# Epoch 23/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9587 - loss: 0.2038
# Epoch 24/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9597 - loss: 0.1963
# Epoch 25/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9597 - loss: 0.1893
# Epoch 26/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9597 - loss: 0.1826
# Epoch 27/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9597 - loss: 0.1763
# Epoch 28/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9597 - loss: 0.1703
# Epoch 29/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9619 - loss: 0.1632
# Epoch 30/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9608 - loss: 0.1550
# Epoch 31/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9608 - loss: 0.1483
# Epoch 32/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9619 - loss: 0.1424
# Epoch 33/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9641 - loss: 0.1362
# Epoch 34/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9641 - loss: 0.1301
# Epoch 35/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9652 - loss: 0.1231
# Epoch 36/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9652 - loss: 0.1140
# Epoch 37/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9663 - loss: 0.1023
# Epoch 38/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9674 - loss: 0.0907
# Epoch 39/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9695 - loss: 0.0798
# Epoch 40/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9782 - loss: 0.0700
# Epoch 41/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9826 - loss: 0.0615
# Epoch 42/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9859 - loss: 0.0543
# Epoch 43/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9869 - loss: 0.0486
# Epoch 44/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9902 - loss: 0.0440
# Epoch 45/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9902 - loss: 0.0400
# Epoch 46/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9935 - loss: 0.0365
# Epoch 47/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9956 - loss: 0.0337
# Epoch 48/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9956 - loss: 0.0311
# Epoch 49/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9956 - loss: 0.0288
# Epoch 50/50
# 29/29 - 0s - 1ms/step - accuracy: 0.9956 - loss: 0.0270

# %%
predictions = np.argmax(model.predict(scaled_X_test), axis=-1)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
model.evaluate(scaled_X_test, y_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.5627 - loss: 0.6473
# [0.6417152881622314, 0.567328929901123]

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[257,   0],
#        [196,   0]], dtype=int64)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.72       257
#          1.0       0.00      0.00      0.00       196
#
#     accuracy                           0.57       453
#    macro avg       0.28      0.50      0.36       453
# weighted avg       0.32      0.57      0.41       453
# c:\Users\user\anaconda3\envs\udemy-cv\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\anaconda3\envs\udemy-cv\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\anaconda3\envs\udemy-cv\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
model.save('mymodel.keras')

# %%
from keras.models import load_model

# %%
new_model = load_model('mymodel.keras')

# %%
new_model.predict(scaled_X_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.21113361],
#        [0.2662913 ],
#        [0.23792021],
#        [0.13235687],
#        [0.2457497 ],
#        [0.27312246],
#        [0.23566332],
#        [0.2710823 ],
#        [0.2898739 ],
#        [0.23947826],
#        [0.35279134],
#        [0.35852733],
#        [0.21661334],
#        [0.31174505],
#        [0.23626277],
#        [0.29550445],
#        [0.34499654],
#        [0.3466781 ],
#        [0.23899888],
#        [0.3085318 ],
#        [0.21295516],
#        [0.24712434],
#        [0.34409523],
#        [0.24133037],
#        [0.3482441 ],
#        [0.26246855],
#        [0.20664324],
#        [0.3241104 ],
#        [0.16382462],
#        [0.21444005],
#        [0.30698115],
#        [0.24484996],
#        [0.25820097],
#        [0.3772975 ],
#        [0.31638464],
#        [0.21723606],
#        [0.35039982],
#        [0.37195006],
#        [0.3529348 ],
#        [0.24051382],
#        [0.20285091],
#        [0.29399943],
#        [0.352746  ],
#        [0.21649149],
#        [0.38338247],
#        [0.28388044],
#        [0.37370026],
#        [0.2484096 ],
#        [0.20189229],
#        [0.29339904],
#        [0.26943046],
#        [0.277375  ],
#        [0.18017156],
#        [0.23576991],
#        [0.25223818],
#        [0.352342  ],
#        [0.12830429],
#        [0.23061907],
#        [0.24761097],
#        [0.19930945],
#        [0.3356951 ],
#        [0.24788505],
#        [0.23415525],
#        [0.18261215],
#        [0.13804764],
#        [0.23075753],
#        [0.25103563],
#        [0.26547652],
#        [0.22825636],
#        [0.22808625],
#        [0.27733576],
#        [0.20628858],
#        [0.2723661 ],
#        [0.24935377],
#        [0.37560737],
#        [0.27641442],
#        [0.27947682],
#        [0.3572089 ],
#        [0.33755657],
#        [0.33402884],
#        [0.29549962],
#        [0.28544232],
#        [0.27101752],
#        [0.19394155],
#        [0.23601276],
#        [0.16349727],
#        [0.2645094 ],
#        [0.39194757],
#        [0.23044407],
#        [0.26012465],
#        [0.2535149 ],
#        [0.2463192 ],
#        [0.34321034],
#        [0.3638307 ],
#        [0.20971686],
#        [0.2564338 ],
#        [0.3530568 ],
#        [0.20195945],
#        [0.20999466],
#        [0.28629753],
#        [0.22096205],
#        [0.28088602],
#        [0.24251156],
#        [0.30423725],
#        [0.40918893],
#        [0.27687818],
#        [0.29311615],
#        [0.27196622],
#        [0.24170898],
#        [0.22806004],
#        [0.31574762],
#        [0.36179635],
#        [0.1734683 ],
#        [0.34755445],
#        [0.32926974],
#        [0.3123043 ],
#        [0.22019215],
#        [0.334618  ],
#        [0.24456845],
#        [0.28905213],
#        [0.23927017],
#        [0.25185516],
#        [0.37425885],
#        [0.20645018],
#        [0.22533104],
#        [0.23298739],
#        [0.32204825],
#        [0.3017423 ],
#        [0.25437516],
#        [0.32224315],
#        [0.3693277 ],
#        [0.13647366],
#        [0.18117802],
#        [0.27667734],
#        [0.16783354],
#        [0.26390326],
#        [0.29754058],
#        [0.15857731],
#        [0.24082142],
#        [0.28477934],
#        [0.2535539 ],
#        [0.25243774],
#        [0.3622986 ],
#        [0.16574657],
#        [0.32546246],
#        [0.2840892 ],
#        [0.26738212],
#        [0.28035945],
#        [0.27805147],
#        [0.24700812],
#        [0.31525016],
#        [0.37196147],
#        [0.23025355],
#        [0.16830844],
#        [0.37312037],
#        [0.25580022],
#        [0.36758152],
#        [0.21826325],
#        [0.26448873],
#        [0.25077718],
#        [0.37876514],
#        [0.32549927],
#        [0.37438688],
#        [0.39790374],
#        [0.37209374],
#        [0.2564626 ],
#        [0.30487764],
#        [0.19974577],
#        [0.23027088],
#        [0.23662259],
#        [0.22865683],
#        [0.2610336 ],
#        [0.27676886],
#        [0.3780646 ],
#        [0.20891285],
#        [0.21803102],
#        [0.34788722],
#        [0.3779088 ],
#        [0.25225914],
#        [0.23397808],
#        [0.17526098],
#        [0.13558364],
#        [0.31005332],
#        [0.20860101],
#        [0.32545754],
#        [0.2604668 ],
#        [0.20584114],
#        [0.3472169 ],
#        [0.1751546 ],
#        [0.26461387],
#        [0.31977352],
#        [0.21205297],
#        [0.25011653],
#        [0.46213463],
#        [0.29705754],
#        [0.38323918],
#        [0.36708605],
#        [0.23430067],
#        [0.24311055],
#        [0.33613282],
#        [0.31337786],
#        [0.34006822],
#        [0.28832012],
#        [0.12960558],
#        [0.3777711 ],
#        [0.4500217 ],
#        [0.4152901 ],
#        [0.30698058],
#        [0.2309817 ],
#        [0.3032719 ],
#        [0.29316562],
#        [0.16928099],
#        [0.2439481 ],
#        [0.27925733],
#        [0.26007625],
#        [0.19565335],
#        [0.27641442],
#        [0.2559507 ],
#        [0.37257895],
#        [0.3196445 ],
#        [0.30505222],
#        [0.36497685],
#        [0.36846966],
#        [0.21512142],
#        [0.34387732],
#        [0.25527138],
#        [0.15669987],
#        [0.2419741 ],
#        [0.22971909],
#        [0.38114026],
#        [0.36317316],
#        [0.24254656],
#        [0.34738797],
#        [0.18258126],
#        [0.2843693 ],
#        [0.32420212],
#        [0.36639583],
#        [0.34427673],
#        [0.26756293],
#        [0.2607376 ],
#        [0.26541817],
#        [0.2616398 ],
#        [0.2663054 ],
#        [0.34460002],
#        [0.3563378 ],
#        [0.32465816],
#        [0.16632436],
#        [0.25033015],
#        [0.2539124 ],
#        [0.20550993],
#        [0.23513764],
#        [0.275795  ],
#        [0.3176104 ],
#        [0.18958192],
#        [0.27685055],
#        [0.27891904],
#        [0.25476173],
#        [0.21331324],
#        [0.36813563],
#        [0.32636884],
#        [0.17027201],
#        [0.17957681],
#        [0.29268306],
#        [0.32080904],
#        [0.34330335],
#        [0.25968742],
#        [0.3563373 ],
#        [0.29591492],
#        [0.3488358 ],
#        [0.3539954 ],
#        [0.33962032],
#        [0.3788932 ],
#        [0.25956604],
#        [0.26629102],
#        [0.17430662],
#        [0.11329191],
#        [0.2607584 ],
#        [0.21231873],
#        [0.2825071 ],
#        [0.25045264],
#        [0.32541835],
#        [0.23209266],
#        [0.34612042],
#        [0.24904035],
#        [0.18590042],
#        [0.27450567],
#        [0.17618035],
#        [0.21254691],
#        [0.27372423],
#        [0.15908806],
#        [0.2731987 ],
#        [0.37678844],
#        [0.34090182],
#        [0.17572597],
#        [0.39584807],
#        [0.2567299 ],
#        [0.34815004],
#        [0.34658185],
#        [0.22392386],
#        [0.29316476],
#        [0.16696084],
#        [0.18961442],
#        [0.20206489],
#        [0.22787812],
#        [0.25040329],
#        [0.2242706 ],
#        [0.37875995],
#        [0.34827524],
#        [0.20904729],
#        [0.24293707],
#        [0.3122589 ],
#        [0.26799875],
#        [0.26548472],
#        [0.26633123],
#        [0.25345975],
#        [0.21723111],
#        [0.2525919 ],
#        [0.20917328],
#        [0.34230235],
#        [0.13164227],
#        [0.32858315],
#        [0.33458647],
#        [0.32621512],
#        [0.2795161 ],
#        [0.2812555 ],
#        [0.2722786 ],
#        [0.21639632],
#        [0.36240447],
#        [0.2671461 ],
#        [0.16465037],
#        [0.13472645],
#        [0.24949142],
#        [0.26520464],
#        [0.2373491 ],
#        [0.22883452],
#        [0.34686372],
#        [0.25729293],
#        [0.18297814],
#        [0.24963994],
#        [0.34104252],
#        [0.29887563],
#        [0.26476818],
#        [0.3396899 ],
#        [0.32740745],
#        [0.16279475],
#        [0.3208034 ],
#        [0.28863022],
#        [0.25361434],
#        [0.2951531 ],
#        [0.27900055],
#        [0.24249339],
#        [0.21535718],
#        [0.31272438],
#        [0.2352652 ],
#        [0.289934  ],
#        [0.17725953],
#        [0.2737364 ],
#        [0.34319898],
#        [0.1903777 ],
#        [0.2430589 ],
#        [0.31385502],
#        [0.20053548],
#        [0.29757205],
#        [0.13254817],
#        [0.16677466],
#        [0.17629606],
#        [0.25467232],
#        [0.28366154],
#        [0.23654534],
#        [0.28881723],
#        [0.3848398 ],
#        [0.2606609 ],
#        [0.14880815],
#        [0.21644892],
#        [0.177765  ],
#        [0.28276014],
#        [0.38522375],
#        [0.22825383],
#        [0.33014038],
#        [0.26372302],
#        [0.35348254],
#        [0.2847116 ],
#        [0.37501514],
#        [0.2773915 ],
#        [0.2961721 ],
#        [0.22697237],
#        [0.22229196],
#        [0.31662306],
#        [0.37082967],
#        [0.22698532],
#        [0.3161803 ],
#        [0.1518846 ],
#        [0.2500594 ],
#        [0.1980478 ],
#        [0.31560087],
#        [0.3531188 ],
#        [0.3215617 ],
#        [0.28460735],
#        [0.22073485],
#        [0.16921476],
#        [0.2622122 ],
#        [0.27291206],
#        [0.12962365],
#        [0.2537801 ],
#        [0.33812827],
#        [0.21462104],
#        [0.3329004 ],
#        [0.37292987],
#        [0.22839703],
#        [0.3804403 ],
#        [0.2541973 ],
#        [0.26670435],
#        [0.3332751 ],
#        [0.2784084 ],
#        [0.23856781],
#        [0.21967421],
#        [0.22063468],
#        [0.37035277],
#        [0.29218403],
#        [0.24520746],
#        [0.262697  ],
#        [0.32251233],
#        [0.3479316 ],
#        [0.2316963 ],
#        [0.2330252 ],
#        [0.18030362],
#        [0.38099968],
#        [0.18816723],
#        [0.27917075],
#        [0.3455488 ],
#        [0.18064155],
#        [0.1777692 ],
#        [0.28106523],
#        [0.14879143],
#        [0.2715376 ],
#        [0.23014843],
#        [0.38521853],
#        [0.15857898],
#        [0.29316476],
#        [0.33425897],
#        [0.26891118],
#        [0.29213402],
#        [0.16637811],
#        [0.15965495],
#        [0.16957971],
#        [0.26239815],
#        [0.35736603],
#        [0.21844292],
#        [0.21962708],
#        [0.2729451 ],
#        [0.25321025],
#        [0.16573867],
#        [0.17526098]], dtype=float32)
